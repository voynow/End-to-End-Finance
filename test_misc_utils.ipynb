# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

import misc_data_utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Using custom function for quick snp500 data scraping
data = misc_data_utils.get_snp_data(start='2013-01-01')
# Out:
# [*********************100%***********************]  505 of 505 completed

# %%
data = misc_data_utils.remove_nan_cols(data)

# %%
growth = misc_data_utils.get_asset_growth(data)

# %%
megagrowth_symbols = growth[:4].index
growth[:4]
# Out:
# TSLA    94.133204
# NVDA    66.163284
# ENPH    43.134564
# AMD     42.513834
# dtype: float64

# %%
# plot of raw data for megagrowth group
plt.figure(figsize=(16, 8))
for col in megagrowth_symbols:
    plt.plot(data["Adj Close", col], label=col, linewidth=2)

plt.legend()
plt.show()

# %%
# plot of data normalized between (0,1) for megagrowth group
plt.figure(figsize=(16, 8))
for col in megagrowth_symbols:
    plt.plot(misc_data_utils.normalize(data["Adj Close", col]), label=col, linewidth=2)

plt.legend()
plt.show()
